# %%
annealing_times = [1, 5, 10, 20, 50]
energies = [12, 10, 9, 8.5, 8.3]

algorithms = ["Offset", "No Offset", "Annealing Opt"]
means = [9.8, 12.0, 9.2]

import numpy as np
matrix = np.random.rand(10, 10)

# %%
# HISTOGRAM
plt.hist(energies, bins=20)
plt.xlabel("Energy")
plt.ylabel("Frequency")
plt.title("Energy Distribution")
plt.show()

# %%
# LINE PLOT
plt.plot(energies)
plt.xlabel("Run Number")
plt.ylabel("Energy")
plt.title("Energy vs Run Index")
plt.show()

# %%
# SCATTER PLOT
plt.scatter(annealing_times, energies)
plt.xlabel("Annealing Time")
plt.ylabel("Energy")
plt.title("Energy vs Annealing Time")
plt.show()

# %%
# BAR CHART
plt.bar(algorithms, means)
plt.ylabel("Average Energy")
plt.title("Algorithm Performance Comparison")
plt.show()

# %%
import pandas as pd

df = pd.DataFrame({
    "Run": range(len(energies)),
    "Energy": energies
})
df
# Out:
#    Run  Energy
# 0    0    12.0
# 1    1    10.0
# 2    2     9.0
# 3    3     8.5
# 4    4     8.3

# %%
plt.imshow(matrix, cmap='viridis')
plt.colorbar()
plt.title("Heatmap of Embedding")
plt.show()
